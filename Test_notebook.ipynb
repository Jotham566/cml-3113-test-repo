# %% [markdown]
# <a href="https://colab.research.google.com/github/Jotham566/cml-3113-test-repo/blob/main/Test_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Code block to take in 2 numbers and return their total***

# %%
a = 2

# %%
b = 3

# %%
total = a + b

# %%
print(total)
# Out:
# 5

# %%
first_name = "Jotham"

# %%
last_name = "Wambi"

# %%
print(first_name, last_name, "The sum of a & b is ", total)
# Out:
# Jotham Wambi The sum of a & b is  5
